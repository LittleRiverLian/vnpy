# %%
# %matplotlib inline

from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt

from dataService import downloadDailyBarBySymbol
from turtleEngine import BacktestingEngine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3f93b397841f> in <module>
#       6 import matplotlib.pyplot as plt
#       7
# ----> 8 from dataService import downloadDailyBarBySymbol
#       9 from turtleEngine import BacktestingEngine
#
# D:\vnstudio\VnFile\CTA\dataService\dataService.py in <module>
#      10 import pandas as pd
#      11
# ---> 12 from vnpy.trader.vtObject import VtBarData, VtTickData
#      13 from vnpy.trader.app.ctaStrategy.ctaBase import (MINUTE_DB_NAME,
#      14                                                  DAILY_DB_NAME,
#
# ModuleNotFoundError: No module named 'vnpy.trader.vtObject'

# %%
def runBacktesting(filename):
    engine = BacktestingEngine()
    engine.setPeriod(datetime(2014, 1, 1), datetime(2019, 6, 30))
    engine.initPortfolio(filename, 10000000)

    engine.loadData()
    engine.runBacktesting()
    engine.showResult()

# %%
runBacktesting("setting_portfolio.csv")
# Out:
# 投资组合的合约代码['AL99', 'CU99', 'RB99', 'ZN99', 'I99', 'J99', 'M99', 'JM99']
# 投资组合的初始价值10000000
# AL99数据加载完成，总数据量：1307
# CU99数据加载完成，总数据量：1307
# RB99数据加载完成，总数据量：1307
# ZN99数据加载完成，总数据量：1307
# I99数据加载完成，总数据量：1307
# J99数据加载完成，总数据量：1307
# M99数据加载完成，总数据量：1307
# JM99数据加载完成，总数据量：1307
# 全部数据加载完成
# 开始回放K线数据
# K线数据回放结束
# 开始统计回测结果
# ------------------------------
# 首个交易日：	2014-01-02 00:00:00
# 最后交易日：	2019-05-15 00:00:00
# 总交易日：	1307
# 盈利交易日	581
# 亏损交易日：	561
# 起始资金：	10000000
# 结束资金：	68,781,448.36
# 总收益率：	587.81%
# 年化收益：	40.42%
# 总盈亏：	58,781,448.36
# 最大回撤: 	-9,043,771.15
# 百分比最大回撤: -37.39%
# 总手续费：	392,983.25
# 总滑点：	602,656.0
# 总成交笔数：	647.0
# 日均盈亏：	44,974.33
# 日均手续费：	300.68
# 日均滑点：	461.1
# 日均成交笔数：	0.0
# 日均收益率：	0.17%
# 收益标准差：	2.05%
# Sharpe Ratio：	1.27

# %%
# 下载数据
downloadDailyBarBySymbol("IF99")
downloadDailyBarBySymbol("I99")
downloadDailyBarBySymbol("CU99")
downloadDailyBarBySymbol("TA99")
downloadDailyBarBySymbol("AL99")
downloadDailyBarBySymbol("RB99")
downloadDailyBarBySymbol("ZN99")
downloadDailyBarBySymbol("M99")
downloadDailyBarBySymbol("J99")
downloadDailyBarBySymbol("JM99")
